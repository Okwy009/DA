# %% [markdown]
# # Pandas Data Management

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# DataFrame Copy
df_original = df.copy()
# The copy() method in pandas is used to create a deep copy of a DataFrame. 
# This means that any changes made to the new DataFrame will not affect the original DataFrame.

# Create new dataframe
df_altered = df_original

# Select the first 6 rows of salary_year_avg from df_altered 
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered.loc[:,'salary_year_avg'].fillna(median_salary)

# %%
# Another way of filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

# %%
# Inspecting the altered DataFrame
df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
# Inspecting the Original DataFrame
df_original.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                1214685406992
# ID of df_altered:                 1214685406992
# Are the two dataframes the same?  True

# %%
df_original = df.copy()
df_altered = df_original.copy()

print('ID of df_original:               ', id(df_original))
print('ID of df_altered:                ', id(df_altered))
print('Are the two dataframes the same? ', id(df_original) == id(df_altered))
# Out:
# ID of df_original:                1214685842384
# ID of df_altered:                 1214685850640
# Are the two dataframes the same?  False

# %%
# Calculating the median salary
median_salary = df_altered['salary_year_avg'].median()

# Filling the missing values with the median salary
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5,'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5,'salary_year_avg']

# See the difference
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
# Sample(): Random sample of items
# Gets 5 random sample of the data


df.sample(n=5)
# Out:
#                   job_title_short  \
# 228112  Machine Learning Engineer
# 538573          Software Engineer
# 723235              Data Engineer
# 141994              Data Engineer
# 610321       Senior Data Engineer
#
#                                           job_title  \
# 228112                    Machine Learning Engineer
# 538573  BI Developer SAP BW4/HANA (m/f/x) (Inhouse)
# 723235                                Data Engineer
# 141994                Service Operations Specialist
# 610321                         Senior Data Engineer
#
#                        job_location                  job_via  \
# 228112     Bogotá, Bogota, Colombia                via BeBee
# 538573  Cologne, Germany (+1 other)            via StepStone
# 723235    Mexico City, CDMX, Mexico         via BeBee México
# 141994                   Luxembourg  via Emplois Trabajo.org
# 610321                 New York, NY         via ZipRecruiter
#
#        job_schedule_type  job_work_from_home       search_location  \
# 228112         Full-time               False              Colombia
# 538573         Full-time               False               Germany
# 723235         Full-time               False                Mexico
# 141994         Full-time               False            Luxembourg
# 610321         Full-time               False  Texas, United States
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 228112 2023-07-22 07:30:13                  False                 False
# 538573 2023-02-12 19:35:52                   True                 False
# 723235 2023-03-26 21:30:18                   True                 False
# 141994 2023-12-13 09:31:12                  False                 False
# 610321 2023-12-10 12:07:59                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 228112       Colombia        None              NaN              NaN
# 538573        Germany        None              NaN              NaN
# 723235         Mexico        None              NaN              NaN
# 141994     Luxembourg        None              NaN              NaN
# 610321  United States        None              NaN              NaN
#
#             company_name                                         job_skills  \
# 228112              Bold  ['python', 'dynamodb', 'aws', 'azure', 'gcp', ...
# 538573          Deloitte                                            ['sap']
# 723235   Connectingology  ['sql', 'sql server', 'mysql', 'power bi', 'ta...
# 141994          Goodyear                                      ['go', 'sap']
# 610321  Publicis Sapient  ['nosql', 'sql', 'python', 'java', 'javascript...
#
#                                           job_type_skills
# 228112  {'cloud': ['aws', 'azure', 'gcp'], 'databases'...
# 538573                         {'analyst_tools': ['sap']}
# 723235  {'analyst_tools': ['power bi', 'tableau'], 'da...
# 141994  {'analyst_tools': ['sap'], 'programming': ['go']}
# 610321  {'cloud': ['azure', 'aws', 'redshift', 'oracle...

# %%
# Randomly select a fraction of the data (10% of the rows), with or without replacement.

df.sample(frac=0.1, replace=False)
# Out:
#               job_title_short  \
# 448453         Data Scientist
# 528937      Software Engineer
# 517892  Senior Data Scientist
# 584129          Data Engineer
# 203700         Data Scientist
# ...                       ...
# 533034       Business Analyst
# 503583          Data Engineer
# 606435  Senior Data Scientist
# 745297         Data Scientist
# 775385           Data Analyst
#
#                                                 job_title  \
# 448453  Principal Product Data Scientist - Client Foun...
# 528937                    Senior Desktop Support Engineer
# 517892                Senior data scientist / ML engineer
# 584129       Principal Data Engineer - Analytics Platform
# 203700                           Data Scientist & Analyst
# ...                                                   ...
# 533034                           Analyst, Master Planning
# 503583  Data Engineer. Job in Brussel My Valley Jobs T...
# 606435                     Senior Data Scientist - Remote
# 745297  Consultant SME (Principal Data Scientist-Data ...
# 775385  Business Data Analyst  Manufacturing Company  ...
#
#                     job_location                   job_via job_schedule_type  \
# 448453    London, UK  (+1 other)             via Hitmarker         Full-time
# 528937  Docklands VIC, Australia      via Jobs Trabajo.org         Full-time
# 517892            Ghent, Belgium      via LinkedIn Belgium         Full-time
# 584129    Amsterdam, Netherlands              via LinkedIn         Full-time
# 203700                 Argentina              via LinkedIn         Full-time
# ...                          ...                       ...               ...
# 533034                 Hong Kong           via Trabajo.org         Full-time
# 503583         Brussels, Belgium  via My Valley Jobs Today         Full-time
# 606435                  Anywhere              via LinkedIn         Full-time
# 745297               Raleigh, NC                  via Dice        Contractor
# 775385                Goleta, CA                 via WayUp         Full-time
#
#         job_work_from_home            search_location     job_posted_date  \
# 448453               False             United Kingdom 2023-05-31 14:19:13
# 528937               False                  Australia 2023-04-18 11:12:56
# 517892               False                    Belgium 2023-07-14 11:56:17
# 584129               False                Netherlands 2023-10-12 10:12:53
# 203700               False                  Argentina 2023-11-14 22:11:57
# ...                    ...                        ...                 ...
# 533034               False                  Hong Kong 2023-01-08 19:40:59
# 503583               False                    Belgium 2023-02-25 11:10:49
# 606435                True                     Poland 2023-10-14 09:15:22
# 745297               False    New York, United States 2023-07-10 20:02:53
# 775385               False  California, United States 2023-06-19 01:00:45
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 448453                  False                 False  United Kingdom
# 528937                   True                 False       Australia
# 517892                  False                 False         Belgium
# 584129                  False                 False     Netherlands
# 203700                  False                 False       Argentina
# ...                       ...                   ...             ...
# 533034                  False                 False       Hong Kong
# 503583                  False                 False         Belgium
# 606435                  False                 False          Poland
# 745297                  False                 False   United States
# 775385                  False                  True   United States
#
#        salary_rate  salary_year_avg  salary_hour_avg         company_name  \
# 448453        None              NaN              NaN                 King
# 528937        None              NaN              NaN              Equifax
# 517892        None              NaN              NaN            BioLizard
# 584129        None              NaN              NaN          Booking.com
# 203700        None              NaN              NaN           NCR Atleos
# ...            ...              ...              ...                  ...
# 533034        None              NaN              NaN           Unicircuit
# 503583        None              NaN              NaN            Datalumen
# 606435        None              NaN              NaN  Akamai Technologies
# 745297        None              NaN              NaN   Lucid Technologies
# 775385        None              NaN              NaN     Your SmartSource
#
#                                                job_skills  \
# 448453                           ['sql', 'excel', 'flow']
# 528937                                        ['windows']
# 517892                                    ['python', 'r']
# 584129  ['java', 'sql', 'python', 'snowflake', 'aws', ...
# 203700              ['sql', 'nosql', 'python', 'tableau']
# ...                                                   ...
# 533034             ['vba', 'word', 'excel', 'powerpoint']
# 503583                                     ['sas', 'sas']
# 606435                          ['python', 'bash', 'sql']
# 745297  ['python', 'perl', 'ruby', 'ruby', 'sas', 'sas...
# 775385  ['sql', 'python', 'power bi', 'outlook', 'word...
#
#                                           job_type_skills
# 448453  {'analyst_tools': ['excel'], 'other': ['flow']...
# 528937                                {'os': ['windows']}
# 517892                   {'programming': ['python', 'r']}
# 584129  {'cloud': ['snowflake', 'aws'], 'libraries': [...
# 203700  {'analyst_tools': ['tableau'], 'programming': ...
# ...                                                   ...
# 533034  {'analyst_tools': ['word', 'excel', 'powerpoin...
# 503583  {'analyst_tools': ['sas'], 'programming': ['sa...
# 606435         {'programming': ['python', 'bash', 'sql']}
# 745297  {'analyst_tools': ['sas'], 'cloud': ['azure', ...
# 775385  {'analyst_tools': ['power bi', 'outlook', 'wor...
#
# [78574 rows x 17 columns]
