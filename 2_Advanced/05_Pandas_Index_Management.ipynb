# %% [markdown]
# # Pandas Index Management

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(3)
# Notice the index has no name
# Out:
#                job_title_short  \
# job_index
# 211935           Data Engineer
# 352089        Business Analyst
# 278688     Senior Data Analyst
#
#                                                    job_title  \
# job_index
# 211935                                   Azure Data Engineer
# 352089     Business Analyst / Data Analyst Consultant bis...
# 278688     Senior Data Analyst. Job in Tallahassee My Val...
#
#                    job_location                   job_via job_schedule_type  \
# job_index
# 211935     Utrecht, Netherlands       via BeBee Nederland         Part-time
# 352089       Frankfurt, Germany                  via XING         Full-time
# 278688          Tallahassee, FL  via My Valley Jobs Today         Full-time
#
#            job_work_from_home search_location     job_posted_date  \
# job_index
# 211935                  False     Netherlands 2023-05-27 22:15:12
# 352089                  False         Germany 2023-09-04 23:18:18
# 278688                  False         Georgia 2023-02-28 07:51:17
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 211935                      True                 False    Netherlands
# 352089                      True                 False        Germany
# 278688                      True                  True  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg  \
# job_index
# 211935           None              NaN              NaN
# 352089           None              NaN              NaN
# 278688           None              NaN              NaN
#
#                                                 company_name  \
# job_index
# 211935                                            Intellerts
# 352089     Beratungsboutiquen / Branchenberatung, bis 25 ...
# 278688                                                Oracle
#
#                                                   job_skills  \
# job_index
# 211935     ['t-sql', 'sql', 'python', 'r', 'postgresql', ...
# 352089                                        ['sas', 'sas']
# 278688     ['sql', 't-sql', 'go', 'sql server', 'oracle',...
#
#                                              job_type_skills
# job_index
# 211935     {'analyst_tools': ['ssis', 'ssrs', 'tableau'],...
# 352089     {'analyst_tools': ['sas'], 'programming': ['sa...
# 278688     {'analyst_tools': ['spreadsheet', 'power bi', ...

# %%
# Inspecting our index

df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df.index.name

# %%
# It has no name... so let's name it

df.index.name = 'job_index'
df.index.name
# Out:
# 'job_index'

# %%
df.sample(3)
# Notice the index name
# Out:
#                 job_title_short  \
# job_index
# 783427     Senior Data Engineer
# 176973           Data Scientist
# 394937     Senior Data Engineer
#
#                                                    job_title  \
# job_index
# 783427                                      Data Engineer Sr
# 176973              Data Visualization Consultant All Levels
# 394937     Remote :: Sr. Data Engineer :: Ft Lauderdale, ...
#
#                    job_location               job_via job_schedule_type  \
# job_index
# 783427          Vienna, Austria  via Jobs Trabajo.org         Full-time
# 176973     Cluj-Napoca, Romania       via Trabajo.org         Full-time
# 394937                 Anywhere              via Dice         Full-time
#
#            job_work_from_home         search_location     job_posted_date  \
# job_index
# 783427                  False                 Austria 2023-01-31 06:30:29
# 176973                  False                 Romania 2023-09-02 15:29:44
# 394937                   True  Florida, United States 2023-10-18 18:09:20
#
#            job_no_degree_mention  job_health_insurance    job_country  \
# job_index
# 783427                      True                 False        Austria
# 176973                      True                 False        Romania
# 394937                     False                  True  United States
#
#           salary_rate  salary_year_avg  salary_hour_avg   company_name  \
# job_index
# 783427           None              NaN              NaN        Open Co
# 176973           None              NaN              NaN      Accenture
# 394937           None              NaN              NaN  KVRA Tech Inc
#
#                                                   job_skills  \
# job_index
# 783427     ['mongodb', 'mongodb', 'java', 'python', 'sql'...
# 176973     ['python', 'java', 'scala', 'sql', 'sap', 'tab...
# 394937                                      ['azure', 'aws']
#
#                                              job_type_skills
# job_index
# 783427     {'cloud': ['aws'], 'databases': ['mongodb', 'p...
# 176973     {'analyst_tools': ['sap', 'tableau'], 'program...
# 394937                           {'cloud': ['azure', 'aws']}

# %%
median_pivot = df.pivot_table(values='salary_year_avg', index='job_title_short', aggfunc='median')
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
index_name = median_pivot.index.name  
index_name
# Out:
# 'job_title_short'

# %%
index_dtype = median_pivot.index.dtype  
index_dtype
# Out:
# dtype('O')

# %% [markdown]
# - reset_index()
#
#    1. Resets the DataFrame’s index to the default integer index.
#    2. This is particularly useful after operations that alter the index, like sorting or filtering, to simplify further data manipulation.

# %%
# Filtering for rows where ‘United States’ is in job_country

df_usa = df[df['job_country'] == 'United States']

df_usa.head(5)
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
df_usa.index

# Since Index is no longer correctly spaced by 1 increment, we reset the index.
# Out:
# Index([     0,      3,      5,      6,      9,     11,     13,     17,     26,
#            27,
#        ...
#        785625, 785626, 785641, 785648, 785651, 785673, 785685, 785692, 785703,
#        785705],
#       dtype='int64', name='job_index', length=206292)

# %%
# Reseting the index and getting top 5
df_usa.reset_index(inplace=True)
df_usa.head()
# Out:
#    index  job_index       job_title_short  \
# 0      0          0  Senior Data Engineer
# 1      1          3         Data Engineer
# 2      2          5         Data Engineer
# 3      3          6  Senior Data Engineer
# 4      4          9        Data Scientist
#
#                                            job_title     job_location  \
# 0  Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 1  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 2                                  GCP Data Engineer         Anywhere
# 3                  Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 4                                  Data Scientist II         Anywhere
#
#              job_via         job_schedule_type  job_work_from_home  \
# 0    via Work Nearby                 Full-time               False
# 1  via Diversity.com                 Full-time               False
# 2   via ZipRecruiter  Contractor and Temp work                True
# 3       via LinkedIn                 Full-time               False
# 4   via ZipRecruiter                 Full-time                True
#
#            search_location     job_posted_date  job_no_degree_mention  \
# 0     Texas, United States 2023-06-16 13:44:15                  False
# 1     Texas, United States 2023-07-04 13:01:41                   True
# 2                  Georgia 2023-11-07 14:01:59                  False
# 3   Florida, United States 2023-03-27 13:18:18                  False
# 4  New York, United States 2023-04-23 13:02:57                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                 False  United States        None              NaN
# 2                 False  United States        None              NaN
# 3                 False  United States        None              NaN
# 4                 False  United States        None              NaN
#
#    salary_hour_avg                   company_name  \
# 0              NaN           Boehringer Ingelheim
# 1              NaN   Southwest Research Institute
# 2              NaN                smart folks inc
# 3              NaN  Miracle Software Systems, Inc
# 4              NaN     Radwell International, LLC
#
#                                           job_skills  \
# 0                                               None
# 1  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2                           ['python', 'sql', 'gcp']
# 3  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 4  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2  {'cloud': ['gcp'], 'programming': ['python', '...
# 3  {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 4  {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
# Reseting the indexes in the pivot table so job_title_short isn't the index anymore.

median_pivot.reset_index(inplace=True)
median_pivot
# Out:
#              job_title_short  salary_year_avg
# 0           Business Analyst          85000.0
# 1             Cloud Engineer          90000.0
# 2               Data Analyst          90000.0
# 3              Data Engineer         125000.0
# 4             Data Scientist         127500.0
# 5  Machine Learning Engineer         106415.0
# 6        Senior Data Analyst         111175.0
# 7       Senior Data Engineer         147500.0
# 8      Senior Data Scientist         155500.0
# 9          Software Engineer          99150.0

# %%
# set_index(): Sets one or more existing columns as the index of the DataFrame.

# Setting job_index as our main index

df_usa.set_index('job_index', inplace=True)

df_usa.head()
# Out:
#            index       job_title_short  \
# job_index
# 0              0  Senior Data Engineer
# 3              1         Data Engineer
# 5              2         Data Engineer
# 6              3  Senior Data Engineer
# 9              4        Data Scientist
#
#                                                    job_title     job_location  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...    Watertown, CT
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio, TX
# 5                                          GCP Data Engineer         Anywhere
# 6                          Senior Data Engineer  - GCP Cloud     Dearborn, MI
# 9                                          Data Scientist II         Anywhere
#
#                      job_via         job_schedule_type  job_work_from_home  \
# job_index
# 0            via Work Nearby                 Full-time               False
# 3          via Diversity.com                 Full-time               False
# 5           via ZipRecruiter  Contractor and Temp work                True
# 6               via LinkedIn                 Full-time               False
# 9           via ZipRecruiter                 Full-time                True
#
#                    search_location     job_posted_date  job_no_degree_mention  \
# job_index
# 0             Texas, United States 2023-06-16 13:44:15                  False
# 3             Texas, United States 2023-07-04 13:01:41                   True
# 5                          Georgia 2023-11-07 14:01:59                  False
# 6           Florida, United States 2023-03-27 13:18:18                  False
# 9          New York, United States 2023-04-23 13:02:57                  False
#
#            job_health_insurance    job_country salary_rate  salary_year_avg  \
# job_index
# 0                         False  United States        None              NaN
# 3                         False  United States        None              NaN
# 5                         False  United States        None              NaN
# 6                         False  United States        None              NaN
# 9                         False  United States        None              NaN
#
#            salary_hour_avg                   company_name  \
# job_index
# 0                      NaN           Boehringer Ingelheim
# 3                      NaN   Southwest Research Institute
# 5                      NaN                smart folks inc
# 6                      NaN  Miracle Software Systems, Inc
# 9                      NaN     Radwell International, LLC
#
#                                                   job_skills  \
# job_index
# 0                                                       None
# 3          ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 5                                   ['python', 'sql', 'gcp']
# 6          ['sql', 'python', 'java', 'sql server', 'gcp',...
# 9          ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                              job_type_skills
# job_index
# 0                                                       None
# 3          {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 5          {'cloud': ['gcp'], 'programming': ['python', '...
# 6          {'cloud': ['gcp', 'bigquery'], 'databases': ['...
# 9          {'analyst_tools': ['excel'], 'cloud': ['azure'...

# %%
# Setting the new index on another column like salary_year_avg

median_pivot.set_index('job_title_short', inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
# sort_index(): Sorts the DataFrame by the index (row labels), either ascending or descending

# Sorting the pivoted DataFrame alphabetically

median_pivot.sort_index(inplace=True)
median_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0
